# %%
import tellurium as te

# %%
r = te.loadSBMLModel('antagonistpn.xml')

# %%
# See all the floating species
species = r.getFloatingSpeciesIds()

# %%
for s in species:
    r.resetToOrigin()
    sim = r.simulate(0,10,100, ['time',s])
    te.plotWithLegend(r,sim)

# %%
import roadrunner
roadrunner.getVersionStr()
# Out:
# '1.2.6; Compiler: gcc 4.6.3, C++ version: 1; JIT Compiler: LLVM-3.4; Date: Oct 29 2014, 21:33:04'
